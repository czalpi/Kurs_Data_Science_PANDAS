# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib as plt

# %%
frame = pd.read_csv("C:/Users/juleq/OneDrive/Desktop/pandas_kurs/course-files/Mcdonalds.csv")

# %% [markdown]
# ## Oczyszczanie danych - fillna()

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame.loc[1, "TotalFat"] = np.NaN
frame.loc[1, "Saturated Fat"] = np.NaN
frame.loc[2, "Saturated Fat"] = np.NaN
frame.loc[2, "Category"] = np.NaN

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2        NaN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       NaN                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#wstawianie wartości w miesjca NaN
frame.fillna(value = 0).head()
#0 dla Category - nie pasuje
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2          0                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            0.0
# 2                200      23.0                         35            0.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
replaceDefinitionTable = {'Category' : 'UNKNOWN', 'TotalFat' : 0, 'Saturated Fat' : 0}

# %%
replaceDefinitionTable
# Out:
# {'Category': 'UNKNOWN', 'TotalFat': 0, 'Saturated Fat': 0}

# %%
frame.fillna(value = replaceDefinitionTable).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2    UNKNOWN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            0.0
# 2                200      23.0                         35            0.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2        NaN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       NaN                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['Category'].fillna(value = 'UNKNOWN', inplace = True)#inplace - zmiana oryginalnego obiektu

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2    UNKNOWN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       NaN                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['TotalFat'].fillna(value = 0, inplace = True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2    UNKNOWN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['Saturated Fat'].fillna(value = 0, inplace = True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2    UNKNOWN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            0.0
# 2                200      23.0                         35            0.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame.loc[1, "TotalFat"] = np.NaN
frame.loc[1, "Saturated Fat"] = np.NaN
frame.loc[2, "Saturated Fat"] = np.NaN
frame.loc[2, "Category"] = np.NaN

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2        NaN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       NaN                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
avgTotalFat = frame['TotalFat'].mean()

# %%
avgTotalFat
# Out:
# 14.18918918918919

# %%
frame['TotalFat'].fillna(avgTotalFat, inplace = True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2        NaN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70  14.189189                         12            NaN
# 2                200  23.000000                         35            NaN
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#można skorzystać z parametru metody, która daje nowe możliwości, np uzupełnienie wartością poprzedzającą
frame['Saturated Fat'].fillna(method = 'ffill', inplace = True) #ffill - forward fill, bill - before fill

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2        NaN                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70  14.189189                         12            5.0
# 2                200  23.000000                         35            5.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ## Sortowanie data frame

# %%
frame1 = pd.read_csv("C:/Users/juleq/OneDrive/Desktop/pandas_kurs/course-files/Mcdonalds.csv",
                    usecols = ['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
frame1.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame1.sort_values(by = 'Calories').head()#argument by wyznacza względem czego sortujemy
# Out:
#          Category                    Item  Serving Size  Calories  TotalFat
# 125     Beverages  Diet Dr Pepper (Child)  12 fl oz cup         0       0.0
# 138  Coffee & Tea       Iced Tea (Medium)  21 fl oz cup         0       0.0
# 137  Coffee & Tea        Iced Tea (Small)  16 fl oz cup         0       0.0
# 136     Beverages     Dasani Water Bottle    16.9 fl oz         0       0.0
# 145  Coffee & Tea          Coffee (Small)  12 fl oz cup         0       0.0

# %%
frame1.sort_values(by = 'Calories', ascending = False).head()#sortowanie malejąco
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  TotalFat
# 82  22.8 oz (646 g)      1880     118.0
# 32  15.3 oz (434 g)      1150      60.0
# 31  14.8 oz (420 g)      1090      56.0
# 34  15.4 oz (437 g)      1050      50.0
# 33  14.9 oz (423 g)       990      46.0

# %%
frame1['Calories'] = frame1['Calories'].astype('float')#bo calories to inty, a tam nie mozna wpisac NaN
frame1.loc[82, 'Calories'] = np.NaN

# %%
frame1.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)     250.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame1.loc[82]
# Out:
# Category                      Chicken & Fish
# Item            Chicken McNuggets (40 piece)
# Serving Size                 22.8 oz (646 g)
# Calories                                 NaN
# TotalFat                               118.0
# Name: 82, dtype: object

# %%
frame1.sort_values(by = 'Calories').tail()#NaN traktowana jest jako wart największa
# Out:
#           Category                                               Item  \
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  TotalFat
# 33  14.9 oz (423 g)     990.0      46.0
# 34  15.4 oz (437 g)    1050.0      50.0
# 31  14.8 oz (420 g)    1090.0      56.0
# 32  15.3 oz (434 g)    1150.0      60.0
# 82  22.8 oz (646 g)       NaN     118.0

# %%
frame1.sort_values(by = 'Calories', na_position = 'first').head()
# Out:
#            Category                          Item     Serving Size  Calories  \
# 82   Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)       NaN
# 114       Beverages             Diet Coke (Small)     16 fl oz cup       0.0
# 139    Coffee & Tea              Iced Tea (Large)     30 fl oz cup       0.0
# 138    Coffee & Tea             Iced Tea (Medium)     21 fl oz cup       0.0
# 137    Coffee & Tea              Iced Tea (Small)     16 fl oz cup       0.0
#
#      TotalFat
# 82      118.0
# 114       0.0
# 139       0.0
# 138       0.0
# 137       0.0

# %%
frame1.sort_values(by = ['Category', 'Item']).head(20)#sortowanie w kolumnie cateogry pod wzgledem nazwy z item
# Out:
#         Category                                       Item  \
# 51   Beef & Pork                     Bacon Clubhouse Burger
# 53   Beef & Pork                             Bacon McDouble
# 42   Beef & Pork                                    Big Mac
# 49   Beef & Pork                               Cheeseburger
# 54   Beef & Pork                               Daily Double
# 50   Beef & Pork                        Double Cheeseburger
# 47   Beef & Pork         Double Quarter Pounder with Cheese
# 48   Beef & Pork                                  Hamburger
# 55   Beef & Pork                            Jalapeño Double
# 52   Beef & Pork                                   McDouble
# 56   Beef & Pork                                      McRib
# 46   Beef & Pork                     Quarter Pounder Deluxe
# 44   Beef & Pork        Quarter Pounder with Bacon & Cheese
# 45   Beef & Pork  Quarter Pounder with Bacon Habanero Ranch
# 43   Beef & Pork                Quarter Pounder with Cheese
# ...

# %%
frame1.sort_values(by = ['Category', 'Item'], ascending = [True, False]).head(20)#category - rosnaco, item - malejaco
# Out:
#         Category                                       Item    Serving Size  \
# 43   Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 45   Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 44   Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 46   Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# 56   Beef & Pork                                      McRib  7.3 oz (208 g)
# 52   Beef & Pork                                   McDouble  5.2 oz (147 g)
# 55   Beef & Pork                            Jalapeño Double  5.6 oz (159 g)
# 48   Beef & Pork                                  Hamburger   3.5 oz (98 g)
# 47   Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# 50   Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# 54   Beef & Pork                               Daily Double  6.7 oz (190 g)
# ...

# %%
frame2 = pd.read_csv("C:/Users/juleq/OneDrive/Desktop/pandas_kurs/course-files/Mcdonalds.csv",
                    usecols = ['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'], index_col = ['Item'])

# %%
frame2.head()#żeby posortować po indeksie, trzeba ten indeks zdefiniować
# Out:
#                                    Category    Serving Size  Calories  \
# Item
# Egg McMuffin                      Breakfast  4.8 oz (136 g)       300
# Egg White Delight                 Breakfast  4.8 oz (135 g)       250
# Sausage McMuffin                  Breakfast  3.9 oz (111 g)       370
# Sausage McMuffin with Egg         Breakfast  5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites  Breakfast  5.7 oz (161 g)       400
#
#                                   TotalFat
# Item
# Egg McMuffin                          13.0
# Egg White Delight                      8.0
# Sausage McMuffin                      23.0
# Sausage McMuffin with Egg             28.0
# Sausage McMuffin with Egg Whites      23.0

# %%
frame2.sort_index(ascending = True).head()
# Out:
#                                      Category       Serving Size  Calories  \
# Item
# 1% Low Fat Milk Jug                 Beverages  1 carton (236 ml)       100
# Apple Slices                   Snacks & Sides      1.2 oz (34 g)        15
# Bacon Buffalo Ranch McChicken  Chicken & Fish     5.7 oz (161 g)       430
# Bacon Cheddar McChicken        Chicken & Fish       6 oz (171 g)       480
# Bacon Clubhouse Burger            Beef & Pork     9.5 oz (270 g)       720
#
#                                TotalFat
# Item
# 1% Low Fat Milk Jug                 2.5
# Apple Slices                        0.0
# Bacon Buffalo Ranch McChicken      21.0
# Bacon Cheddar McChicken            24.0
# Bacon Clubhouse Burger             40.0

# %% [markdown]
# ## Kontrola i optymalizacja typów

# %%
frame3 = pd.read_csv("C:/Users/juleq/OneDrive/Desktop/pandas_kurs/course-files/Mcdonalds.csv",
                    usecols = ['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
frame3.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame3.dtypes
# Out:
# Category         object
# Item             object
# Serving Size     object
# Calories          int64
# TotalFat        float64
# dtype: object

# %%
frame3.info(memory_usage = 'deep')#jesli bedzie NaN to nei da rady przekonwertowac na typ int
#memory_usage - ile pamieci dokladnie jest zajete
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Item          260 non-null    object
#  2   Serving Size  260 non-null    object
#  3   Calories      260 non-null    int64
#  4   TotalFat      260 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 61.7 KB

# %%
frame3.loc[1, 'Serving Size'] = np.NaN

# %%
frame3.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight             NaN       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame3.loc[3, 'Calories'] = np.NaN
frame3.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight             NaN     250.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       NaN
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame3.info(memory_usage = 'deep')#kolumna calories zmienila typ na float64 z int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Item          260 non-null    object
#  2   Serving Size  259 non-null    object
#  3   Calories      259 non-null    float64
#  4   TotalFat      260 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 61.6 KB

# %%
#powrot kolumny calories z powrotem na typo int64
#frame3['Calories'].astype('int')#nie da rady NaN na int
frame3['Calories'].fillna(value = 0, inplace = True)
frame3.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight             NaN     250.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       0.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame3['Calories'] = frame3['Calories'].astype('int')
frame3.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight             NaN       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)         0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame3.info(memory_usage = 'deep') #udana zmiana na int32, tym lepiej, bo zmiejszony został rozmiar danych
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Item          260 non-null    object
#  2   Serving Size  259 non-null    object
#  3   Calories      260 non-null    int32
#  4   TotalFat      260 non-null    float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 60.6 KB

# %%
#inwentaryzowanie problemu
frame3['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
frame3['Category'] = frame3['Category'].astype('category')#zbieżność nazw

# %%
frame3.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight             NaN       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)         0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame3.info(memory_usage = 'deep')#kolumna Cateogry opisana jako category a nie object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    category
#  1   Item          260 non-null    object
#  2   Serving Size  259 non-null    object
#  3   Calories      260 non-null    int32
#  4   TotalFat      260 non-null    float64
# dtypes: category(1), float64(1), int32(1), object(2)
# memory usage: 44.3 KB

# %%
frame3['Serving Size'].value_counts()
# Out:
# 16 fl oz cup       45
# 12 fl oz cup       38
# 22 fl oz cup       20
# 20 fl oz cup       16
# 30 fl oz cup        7
#                    ..
# 7.4 oz (211 g)      1
# 4 oz (114 g)        1
# 2 oz (56 g)         1
# 6.8 oz (192 g)      1
# 14.2 oz (403 g)     1
# Name: Serving Size, Length: 106, dtype: int64

# %%
frame3['Serving Size'] = frame3['Serving Size'].astype('category')

# %%
frame3.info(memory_usage = 'deep')#zmniejszenie pamieci z ok 61KB na 38KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    category
#  1   Item          260 non-null    object
#  2   Serving Size  259 non-null    category
#  3   Calories      260 non-null    int32
#  4   TotalFat      260 non-null    float64
# dtypes: category(2), float64(1), int32(1), object(1)
# memory usage: 38.2 KB

# %% [markdown]
# ## Ranking
# Ranking to nie tylko sortowanie danych, to również przypisanie określonych miejsc w tym rankingu wszystkich obiektów, które występują w danych

# %%
frame4 = pd.read_csv("C:/Users/juleq/OneDrive/Desktop/pandas_kurs/course-files/Mcdonalds.csv",
                    usecols = ['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
frame4.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame4['Calories'].rank().head()#rank() domyślnie zwraca serię
# Out:
# 0    115.0
# 1     82.5
# 2    146.0
# 3    178.5
# 4    156.0
# Name: Calories, dtype: float64

# %% [markdown]
# Wady rankingu:
# 1. widzimy to w serii a nie w nowej kolumnie dołączonej do data frame
# 2. nie ma możliwości zweryfikowania, czemu dany obiekt jest na tym konkretnym miejscu i czy dobrze sa ustawione, a to dlatego ze dane nie sa posortowane ze wzgledu an kalorie
# 3. Ranking zbudowaliśmy tak ze zaczyna sie od dan najmniej kalorycznych

# %%
frame4['Calories Rank'] = frame4['Calories'].rank()

# %%
frame4.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat  Calories Rank
# 0      13.0          115.0
# 1       8.0           82.5
# 2      23.0          146.0
# 3      28.0          178.5
# 4      23.0          156.0

# %%
frame4.sort_values(by = 'Calories').head(20)#jest troche rzeczy ktore maja 8 kalorii, dlatego zostało im przypisane po 8.5
# Out:
#            Category                              Item      Serving Size  \
# 125       Beverages            Diet Dr Pepper (Child)      12 fl oz cup
# 138    Coffee & Tea                 Iced Tea (Medium)      21 fl oz cup
# 137    Coffee & Tea                  Iced Tea (Small)      16 fl oz cup
# 136       Beverages               Dasani Water Bottle        16.9 fl oz
# 145    Coffee & Tea                    Coffee (Small)      12 fl oz cup
# 147    Coffee & Tea                    Coffee (Large)      16 fl oz cup
# 124       Beverages            Diet Dr Pepper (Large)      30 fl oz cup
# 139    Coffee & Tea                  Iced Tea (Large)      30 fl oz cup
# 122       Beverages            Diet Dr Pepper (Small)      16 fl oz cup
# 123       Beverages           Diet Dr Pepper (Medium)      21 fl oz cup
# 117       Beverages                 Diet Coke (Child)      12 fl oz cup
# 116       Beverages                 Diet Coke (Large)      30 fl oz cup
# ...

# %%
frame4['Calories Rank'] = frame4['Calories'].rank(ascending = False)#chcemy ustawić malejąco

# %%
frame4.sort_values(by = 'Calories', ascending = False).head(10)
# Out:
#                Category                                               Item  \
# 82       Chicken & Fish                       Chicken McNuggets (40 piece)
# 32            Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31            Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34            Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33            Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 81       Chicken & Fish                       Chicken McNuggets (20 piece)
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 246  Smoothies & Shakes                           Strawberry Shake (Large)
# 251  Smoothies & Shakes                             Shamrock Shake (Large)
#
#         Serving Size  Calories  TotalFat  Calories Rank
# 82   22.8 oz (646 g)      1880     118.0            1.0
# ...

# %%
#po pozycji 7 nie ma 8 ani 9 jest za to 8.5 i to podwojnie
#Ranking to nie tlyko uporzadkowanie danych, ale bardziej nadanie numerow poszczegolnym elementom ze wzgledu na cos

# %%
#3 najbardziej kaloryczne dania w menu
#metoda I
frame4.sort_values(by = 'Calories', ascending = False, inplace = True)
frame4.head(3)
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  Calories Rank
# 82  22.8 oz (646 g)      1880     118.0            1.0
# 32  15.3 oz (434 g)      1150      60.0            2.0
# 31  14.8 oz (420 g)      1090      56.0            3.0

# %%
#metoda II - dedykowana do tego funkcja
frame4.nlargest(n = 3, columns = 'Calories')
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  Calories Rank
# 82  22.8 oz (646 g)      1880     118.0            1.0
# 32  15.3 oz (434 g)      1150      60.0            2.0
# 31  14.8 oz (420 g)      1090      56.0            3.0

# %%
#3 najmniej kaloryczne dania w menu
frame4.tail(3)#można tak bo już są posortowane malejąco
# Out:
#          Category                    Item  Serving Size  Calories  TotalFat  \
# 138  Coffee & Tea       Iced Tea (Medium)  21 fl oz cup         0       0.0
# 139  Coffee & Tea        Iced Tea (Large)  30 fl oz cup         0       0.0
# 125     Beverages  Diet Dr Pepper (Child)  12 fl oz cup         0       0.0
#
#      Calories Rank
# 138          252.5
# 139          252.5
# 125          252.5

# %%
frame4.nsmallest(n = 3, columns = 'Calories')#są to zupełnie inne produkty niż wyżej, ale nadal poprawnie
# Out:
#       Category                     Item  Serving Size  Calories  TotalFat  \
# 116  Beverages        Diet Coke (Large)  30 fl oz cup         0       0.0
# 123  Beverages  Diet Dr Pepper (Medium)  21 fl oz cup         0       0.0
# 117  Beverages        Diet Coke (Child)  12 fl oz cup         0       0.0
#
#      Calories Rank
# 116          252.5
# 123          252.5
# 117          252.5

# %% [markdown]
# ## Filtrowanie danych w data frame

# %%
frame5 = pd.read_csv("C:/Users/juleq/OneDrive/Desktop/pandas_kurs/course-files/Mcdonalds.csv",
                    usecols = ['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
frame5.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
#produkty mające więcej niż400 kalorii
(frame['Calories'] >= 400).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Calories, dtype: bool

# %%
(frame['TotalFat'] <= 20).head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: TotalFat, dtype: bool

# %%
caloriesGreaterEqual400 = frame['Calories'] >= 400

# %%
totalfatLessEqual20 = frame['TotalFat'] <= 20

# %%
frame5[caloriesGreaterEqual400].head()#wszystkie elementy w zwracanym obiekcie muszą spełniać zadany warunek
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  TotalFat
# 3       450      28.0
# 4       400      23.0
# 5       430      23.0
# 6       460      26.0
# 7       520      30.0

# %%
frame5[totalfatLessEqual20].head()
# Out:
#      Category                                               Item  \
# 0   Breakfast                                       Egg McMuffin
# 1   Breakfast                                  Egg White Delight
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 16  Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
#
#       Serving Size  Calories  TotalFat
# 0   4.8 oz (136 g)       300      13.0
# 1   4.8 oz (135 g)       250       8.0
# 8   5.4 oz (153 g)       410      20.0
# 16    5 oz (143 g)       410      20.0
# 20  6.3 oz (178 g)       400      15.0

# %%
#Można połączyć ze sobą te 2 metody
(frame5[frame5['Calories'] >= 400]).head() #ale jest to niebezpieczne
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  TotalFat
# 3       450      28.0
# 4       400      23.0
# 5       430      23.0
# 6       460      26.0
# 7       520      30.0

# %%
isBreakfast = frame5['Category'] == 'Breakfast'

# %%
frame5[isBreakfast & caloriesGreaterEqual400].head()#połączenie 2 warunków
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  TotalFat
# 3       450      28.0
# 4       400      23.0
# 5       430      23.0
# 6       460      26.0
# 7       520      30.0

# %%
frame5[isBreakfast & totalfatLessEqual20 & caloriesGreaterEqual400].head()#3 warunki też można połączy bitowym operatorem &(and)
# Out:
#      Category                                               Item  \
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 16  Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 39  Breakfast                                     Cinnamon Melts
#
#       Serving Size  Calories  TotalFat
# 8   5.4 oz (153 g)       410      20.0
# 16    5 oz (143 g)       410      20.0
# 20  6.3 oz (178 g)       400      15.0
# 39    4 oz (114 g)       460      19.0

# %%
frame5[~isBreakfast].head()#negacja, pokazane sa te dania ktore nie sa sniadaniami
# Out:
#        Category                                       Item    Serving Size  \
# 42  Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 43  Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 44  Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 45  Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 46  Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
#
#     Calories  TotalFat
# 42       530      27.0
# 43       520      26.0
# 44       600      29.0
# 45       610      31.0
# 46       540      27.0

# %%
color = ['green', 'green', 'blue', 'blue', 'red', 'red', 'white']
size = ['S', 'S', 'S', 'M', 'M', 'M', 'L']
gender =  ['M', 'W', 'M', 'W', 'M', 'W', 'U']
clothes = pd.DataFrame({'color' : color, 'size' : size, 'gender' : gender})
clothes
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W
# 6  white    L      U

# %%
isColorBlue = clothes['color'] == 'blue'
isColorGreen = clothes['color'] == 'green'
isColorRed = clothes['color'] == 'red'
isGenderM = clothes['gender'] == 'M'
isGenderW = clothes['gender'] == 'W'
isSizeS = clothes['size'] == 'S'
isSizeM = clothes['size'] == 'M'
isSizeL = clothes['size'] == 'L'

# %%
clothes[isGenderM & isColorBlue & isSizeS]#kolejność podawania warunkow nie ma znaczenia
# Out:
#   color size gender
# 2  blue    S      M

# %%
clothes[isGenderM | isColorBlue | isSizeS]#nadal kolejnosc nie ma znaczenia, | - lub
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M

# %%
clothes[isGenderM & isColorBlue | isSizeM]#mnozenie jako pierwsze, wiec tutaj najpierw wykonywany jest warunek &
# Out:
#   color size gender
# 2  blue    S      M
# 3  blue    M      W
# 4   red    M      M
# 5   red    M      W

# %%
clothes[isSizeM | isColorBlue & isGenderM]#zmiana kolejnośći warunków, ale bez zmiany operatoró miedzy nimi
# Out:
#   color size gender
# 2  blue    S      M
# 3  blue    M      W
# 4   red    M      M
# 5   red    M      W

# %%
clothes[(isSizeM | isColorBlue) & isGenderM]
# Out:
#   color size gender
# 2  blue    S      M
# 4   red    M      M

# %% [markdown]
# Kolejność warunkow podawanych w instrukcjach filtrujacych dane poddawane sa tym samym regulom co operacje arytmetyczne

# %%
clothes[(clothes['size'] == 'M')| (clothes['color'] == 'blue') & isGenderM]
